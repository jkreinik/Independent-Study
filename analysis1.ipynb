# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.formula.api as smf
import statsmodels.api as sm
import seaborn as sns
# Out:
# /Users/jacobkreinik/anaconda/envs/si370/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
xls = pd.ExcelFile('women_soccer_games.xls')

# %%
df1 = pd.read_excel(xls, 'Session')

# %%
df1
# Out:
#              Player Name Period Name  Activity Name  Period Number  \
# 0        Serena Williams     Session        WV Game              0
# 1           Luisa Moreno     Session        WV Game              0
# 2     Arabella Mansfield     Session        WV Game              0
# 3              Ida Wells     Session        WV Game              0
# 4             Sally Ride     Session        WV Game              0
# 5             Bell Abzug     Session        WV Game              0
# 6          Toni Morrison     Session        WV Game              0
# 7         Amelia Earhart     Session        WV Game              0
# 8        Wilma Mankiller     Session        WV Game              0
# 9          Wilma Rudolph     Session        WV Game              0
# 10         Rachel Carson     Session        WV Game              0
# 11             Besy Ross     Session        WV Game              0
# 12       Barbara Walters     Session        WV Game              0
# ...

# %%
df1[['Home/Away', 'Total Distance']].groupby("Home/Away").mean()
# Out:
#            Total Distance
# Home/Away
# Away          8720.198918
# Home          8092.259638

# %%
df1.groupby(["Home/Away", 'Activity Name']).mean()['High Speed distance']
# Out:
# Home/Away  Activity Name
# Away       Illiniois          515.860002
#            Indiana            682.095884
#            Iowa Game          765.572853
#            Marquette          629.748666
#            Minnesota (2)      654.749413
#            Nebraska Game      703.307688
#            Northwestern       560.877500
#            WV Game            133.105332
# Home       Illinois St        889.676000
#            Marshall Game      318.770714
#            Maryland           558.388822
#            Michigan State     611.442354
#            Minnesota          730.179374
#            Notre Dame Game    532.546434
#            OSU                631.797498
#            Ole Miss game      661.512501
#            Pitt Game          309.200665
#            Rutgers            566.503124
#            UC-Riverside       655.866669
#            Virginia Game      163.057500
#            Wisconsin          721.374003
#            Wisconsin (2)      729.205627
# ...

# %%
df1.groupby(["Home/Away"]).mean()['High Speed distance']
# Out:
# Home/Away
# Away    578.821451
# Home    585.514645
# Name: High Speed distance, dtype: float64

# %%
df1.groupby(["Win/Loss/Tie",'Home/Away']).mean()['Total Distance']
# Out:
# Win/Loss/Tie  Home/Away
# Loss          Away          8568.756939
#               Home          8130.842840
# Tie           Away          5370.027565
#               Home          9028.304757
# Win           Away         10086.023893
#               Home          7402.110546
# Name: Total Distance, dtype: float64

# %%
big_wins = df1[df1['MOV/MOL'] >= 2]
big_wins.mean()['Total Distance']
# Out:
# 7232.6924878082191

# %%
df1.groupby("Big Ten").mean()['Total Distance']
# Out:
# Big Ten
# No     8109.321197
# Yes    8457.866359
# Name: Total Distance, dtype: float64

# %%
big_ten_td = df1.groupby("Big Ten").mean()['Total Distance']
big_ten_td.plot.bar()
